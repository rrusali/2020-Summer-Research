# %%
import pandas as pd
import numpy as np
import os

# %%
# path1 = "E:/Old Downloads Folder/Research Stuff/Jupyter Notebooks/Coords Folder/Heat Map/Pittsburgh/0.05/"
# path2 = '.txt'

# full_frame = pd.DataFrame()

# for i in range(1, 403):
#     openpath = path1 + str(i) + path2
#     frame = pd.read_csv(openpath, sep=',', skiprows=[0], header=None)
#     val = frame[0].max()/frame[0].sum()
#     temp_frame = pd.DataFrame([val])
#     full_frame = pd.concat([full_frame, temp_frame], ignore_index=True)

# full_frame.index = full_frame.index + 1

# savepath = 'E:/Old Downloads Folder/Research Stuff/Jupyter Notebooks/Coords Folder/Heat Map/Pittsburgh/'
# full_frame.to_csv(savepath + 'HeatMap.csv')

# %%
path = 'E:/Old Downloads Folder/Research Stuff/Jupyter Notebooks/Coords Folder/Heat Map/Los Angeles/'
files = os.listdir(path)
ids = []

for file in files:
    num = file[:file.find('_')]
    if num not in ids:
        ids.append(num)

# %%
ids
# Out:
# ['1000',
#  '1001',
#  '1002',
#  '1003',
#  '1004',
#  '1005',
#  '1006',
#  '1007',
#  '1008',
#  '1009',
#  '1010',
#  '1011',
#  '1012',
#  '1013',
#  '1014',
#  '1015',
#  '1016',
#  '1017',
#  '1018',
#  '1019',
#  '1020',
#  '1021',
#  '1022',
#  '1023',
#  '1024',
#  '1025',
#  '1026',
#  '1027',
#  '1028',
#  '1029',
#  '1030',
#  '1031',
#  '1032',
#  '1033',
#  '1034',
#  '1035',
#  '1036',
#  '1037',
#  '1038',
#  '1039',
#  '1040',
#  '1041',
#  '1042',
#  '1043',
#  '1044',
#  '1045',
#  '1046',
#  '1047',
#  '1048',
#  '1049',
#  '1050',
#  '1051',
#  '1052',
#  '1053',
#  '1054',
#  '1055',
#  '1056',
#  '1057',
#  '1058',
#  '1059',
#  '1060',
#  '1061',
#  '1062',
#  '1063',
#  '1064',
#  '1065',
#  '1066',
#  '1067',
#  '1068',
#  '1069',
#  '1070',
#  '1071',
#  '1072',
#  '1073',
#  '1074',
#  '1075',
#  '1076',
#  '1077',
#  '1078',
#  '1079',
#  '1080',
#  '1081',
#  '1082',
#  '1083',
#  '1084',
#  '1085',
#  '1086',
#  '1087',
#  '1088',
#  '1089',
# ...
